# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
listing_csv = "Data Files for AirBnB Project/detail listings.csv"

# %%
listing_df = pd.read_csv(listing_csv, low_memory=False)

# %%
listing_df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3362  https://www.airbnb.com/rooms/3362  20190211014849   2019-02-11
# 1  3662  https://www.airbnb.com/rooms/3662  20190211014849   2019-02-11
# 2  3686  https://www.airbnb.com/rooms/3686  20190211014849   2019-02-11
# 3  3771  https://www.airbnb.com/rooms/3771  20190211014849   2019-02-11
# 4  4002  https://www.airbnb.com/rooms/4002  20190211014849   2019-02-11
#
#                                                 name  \
# 0  Convention Center Rowhouse & In Law: 2 Units, 4BR
# 1                                 Vita's Hideaway II
# 2                                    Vita's Hideaway
# 3                                       Mt. Pleasant
# 4       2 Bedroom Private Condo Suite (Basement Apt)
#
#                                              summary  \
# 0  An architect-designed rowhouse featuring a lar...
# 1  IMPORTANT NOTES * Carefully read and be sure t...
# ...

# %%
#Ideas for cleaning data: 
    #Consider removing the following columns: scrape id, listing id, urls
        #Remove free form
        #Remove URL
        #
    #See if other data should be merged
    #create code for empty cells/non data
    #columns 61/62 need to be cleaned (dtype should be specified - pulled in as Low Memory to override for now)
