# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# File path to listings.csv
dlistings_csv_path = "Data Files for AirBnB Project/detail listings.csv"

#read listings.csv into a database
dlistings_df = pd.read_csv(dlistings_csv_path)
dlistings_df.head()
#len(dlistings_df)
# Out:
# C:\Users\Kate Prevost\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      id                        listing_url       scrape_id last_scraped  \
# 0  3362  https://www.airbnb.com/rooms/3362  20190211014849   2019-02-11
# 1  3662  https://www.airbnb.com/rooms/3662  20190211014849   2019-02-11
# 2  3686  https://www.airbnb.com/rooms/3686  20190211014849   2019-02-11
# 3  3771  https://www.airbnb.com/rooms/3771  20190211014849   2019-02-11
# 4  4002  https://www.airbnb.com/rooms/4002  20190211014849   2019-02-11
#
#                                                 name  \
# 0  Convention Center Rowhouse & In Law: 2 Units, 4BR
# 1                                 Vita's Hideaway II
# 2                                    Vita's Hideaway
# 3                                       Mt. Pleasant
# 4       2 Bedroom Private Condo Suite (Basement Apt)
#
#                                              summary  \
# 0  An architect-designed rowhouse featuring a lar...
# 1  IMPORTANT NOTES * Carefully read and be sure t...
# 2  IMPORTANT NOTES * Carefully read and be sure t...
# 3  Clean, convenient and welcoming home.  Bedroom...
# 4  This is a very large beautiful English BASEMEN...
#
#                                                space  \
# 0  This listing features our 19th century Victori...
# 1  IMPORTANT NOTES * Airbnb keeps accurate track ...
# 2  IMPORTANT NOTES * Airbnb keeps accurate track ...
# 3  Spacious, clean, convenient and welcoming home...
# 4  This is a very large (1400 SQ feet) beautiful ...
#
#                                          description experiences_offered  \
# 0  An architect-designed rowhouse featuring a lar...                none
# 1  IMPORTANT NOTES * Carefully read and be sure t...                none
# 2  IMPORTANT NOTES * Carefully read and be sure t...                none
# 3  Clean, convenient and welcoming home.  Bedroom...                none
# 4  This is a very large beautiful English BASEMEN...                none
#
#                                neighborhood_overview        ...          \
# 0                                                NaN        ...
# 1  We love that our neighborhood is up and coming...        ...
# 2  We love that our neighborhood is up and coming...        ...
# 3                                                NaN        ...
# 4                 This is a very quite neighborhood.        ...
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                t                        f  strict_14_with_grace_period
# 1                f                        f                     moderate
# 2                f                        f                     moderate
# 3                f                        f                     moderate
# 4                t                        f                     flexible
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                t
#
#    calculated_host_listings_count  \
# 0                               5
# 1                               3
# 2                               3
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            5
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            3
# 2                                            3
# 3                                            1
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.27
# 1                                            0               0.37
# 2                                            0               0.67
# 3                                            0               0.01
# 4                                            0               1.22
#
# [5 rows x 106 columns]

# %%
###  only necessary columns
dlistings_df = dlistings_df[["id", "neighbourhood_cleansed", "zipcode", "latitude", "longitude", "property_type", "room_type", "price",  
                            "review_scores_rating", "reviews_per_month"]]
dlistings_df.rename(columns={'neighbourhood_cleansed': 'neighbourhood'}, inplace=True)
dlistings_df.head()
# Out:
#      id                                      neighbourhood zipcode   latitude  \
# 0  3362                                 Shaw, Logan Circle   20001  38.910461
# 1  3662                                 Historic Anacostia   20020  38.861925
# 2  3686                                 Historic Anacostia   20020  38.863138
# 3  3771  Columbia Heights, Mt. Pleasant, Pleasant Plain...   20009  38.927605
# 4  4002  North Michigan Park, Michigan Park, University...   20017  38.940084
#
#    longitude property_type        room_type    price  review_scores_rating  \
# 0 -77.019331     Townhouse  Entire home/apt  $433.00                  96.0
# 1 -76.989634         House     Private room   $65.00                  94.0
# 2 -76.988362         House     Private room   $55.00                  91.0
# 3 -77.039265         Other     Private room   $88.00                   NaN
# 4 -76.989360         House  Entire home/apt  $120.00                  85.0
#
#    reviews_per_month
# 0               1.27
# 1               0.37
# 2               0.67
# 3               0.01
# 4               1.22

# %%
###  filter by room_type='entire house'
nothouse = dlistings_df[dlistings_df["room_type"] != "Entire home/apt" ].index
 
# Delete these row indexes from dataFrame
dlistings_df.drop(nothouse , inplace=True)

dlistings_df.head()
# Out:
#       id                                      neighbourhood zipcode  \
# 0   3362                                 Shaw, Logan Circle   20001
# 4   4002  North Michigan Park, Michigan Park, University...   20017
# 6   4283     Kalorama Heights, Adams Morgan, Lanier Heights   20009
# 10  5589     Kalorama Heights, Adams Morgan, Lanier Heights   20009
# 15  9641         Dupont Circle, Connecticut Avenue/K Street   20005
#
#      latitude  longitude property_type        room_type    price  \
# 0   38.910461 -77.019331     Townhouse  Entire home/apt  $433.00
# 4   38.940084 -76.989360         House  Entire home/apt  $120.00
# 6   38.922032 -77.044474     Apartment  Entire home/apt  $135.00
# 10  38.919327 -77.041238     Apartment  Entire home/apt  $118.00
# 15  38.911465 -77.036361          Loft  Entire home/apt  $195.00
#
#     review_scores_rating  reviews_per_month
# 0                   96.0               1.27
# 4                   85.0               1.22
# 6                  100.0               0.12
# 10                  90.0               0.70
# 15                  95.0               1.23

# %%
###  Convert the price column from string to float  ###
#remove the $'s'
dlistings_df['price'] = [x.replace("$", "") for x in dlistings_df["price"]]
#remove the ,'s'
dlistings_df['price'] = [x.replace(",", "") for x in dlistings_df["price"]]
#convert to 
dlistings_df['price'] = dlistings_df['price'].astype(float)
dlistings_df.head()
# Out:
#       id                                      neighbourhood zipcode  \
# 0   3362                                 Shaw, Logan Circle   20001
# 4   4002  North Michigan Park, Michigan Park, University...   20017
# 6   4283     Kalorama Heights, Adams Morgan, Lanier Heights   20009
# 10  5589     Kalorama Heights, Adams Morgan, Lanier Heights   20009
# 15  9641         Dupont Circle, Connecticut Avenue/K Street   20005
#
#      latitude  longitude property_type        room_type  price  \
# 0   38.910461 -77.019331     Townhouse  Entire home/apt  433.0
# 4   38.940084 -76.989360         House  Entire home/apt  120.0
# 6   38.922032 -77.044474     Apartment  Entire home/apt  135.0
# 10  38.919327 -77.041238     Apartment  Entire home/apt  118.0
# 15  38.911465 -77.036361          Loft  Entire home/apt  195.0
#
#     review_scores_rating  reviews_per_month
# 0                   96.0               1.27
# 4                   85.0               1.22
# 6                  100.0               0.12
# 10                  90.0               0.70
# 15                  95.0               1.23

# %%
#create a table finding the max, min and median price for each neighborhood
prcbyhood_dfg = dlistings_df.groupby(["neighbourhood", "room_type"]).agg({"price":["max","min","median", "mean"]})
#remove the 'price' level
prcbyhood_dfg.columns = prcbyhood_dfg.columns.droplevel()

prcbyhood_dfg.rename(columns={'max':'max rent', 'min':'min rent', 'median':'median rent', 'mean':'mean rent'}, inplace=True)
#reset index to remove mult-index
prcbyhood_dfg = prcbyhood_dfg.rename_axis(['neighbourhood', 'Room_type']).reset_index()

prcbyhood_dfg.head(20)
# Out:
#                                         neighbourhood        Room_type  \
# 0                Brightwood Park, Crestwood, Petworth  Entire home/apt
# 1                       Brookland, Brentwood, Langdon  Entire home/apt
# 2                          Capitol Hill, Lincoln Park  Entire home/apt
# 3     Capitol View, Marshall Heights, Benning Heights  Entire home/apt
# 4      Cathedral Heights, McLean Gardens, Glover Park  Entire home/apt
# 5   Cleveland Park, Woodley Park, Massachusetts Av...  Entire home/apt
# 6   Colonial Village, Shepherd Park, North Portal ...  Entire home/apt
# 7   Columbia Heights, Mt. Pleasant, Pleasant Plain...  Entire home/apt
# 8    Congress Heights, Bellevue, Washington Highlands  Entire home/apt
# 9   Deanwood, Burrville, Grant Park, Lincoln Heigh...  Entire home/apt
# 10                           Douglas, Shipley Terrace  Entire home/apt
# 11  Downtown, Chinatown, Penn Quarters, Mount Vern...  Entire home/apt
# 12         Dupont Circle, Connecticut Avenue/K Street  Entire home/apt
# 13                       Eastland Gardens, Kenilworth  Entire home/apt
# 14  Edgewood, Bloomingdale, Truxton Circle, Eckington  Entire home/apt
# 15  Fairfax Village, Naylor Gardens, Hillcrest, Su...  Entire home/apt
# 16  Friendship Heights, American University Park, ...  Entire home/apt
# 17                    Georgetown, Burleith/Hillandale  Entire home/apt
# 18              Hawthorne, Barnaby Woods, Chevy Chase  Entire home/apt
# 19                                 Historic Anacostia  Entire home/apt
#
#     max rent  min rent  median rent   mean rent
# 0     2500.0      35.0        100.0  180.629139
# 1     1638.0      42.0         91.5  174.714286
# 2     5995.0      50.0        150.0  264.990783
# 3      450.0      30.0         99.0  132.052632
# 4     1500.0      50.0        115.0  272.604938
# 5     2400.0      40.0        119.5  237.836735
# 6      850.0      50.0        110.0  222.000000
# 7     2000.0      10.0        115.0  177.593640
# 8     1000.0      55.0        100.0  170.272727
# 9      500.0      35.0         82.5  129.500000
# 10    1250.0      39.0         82.5  251.900000
# 11    5500.0      45.0        200.0  329.370474
# 12    2000.0      39.0        148.5  204.551546
# 13     210.0      85.0        100.0  131.666667
# 14    2500.0      40.0        125.0  205.553611
# 15     350.0      74.0        120.0  151.533333
# 16     800.0      50.0        125.0  166.573770
# 17   10000.0      60.0        180.0  335.868020
# 18    3500.0      50.0        146.5  417.972222
# 19     700.0      65.0         90.0  179.777778

# %%
#create a table finding the max, min and median price for each neighborhood
ratebyhood_dfg = dlistings_df.groupby(["neighbourhood", "room_type"]).agg({"review_scores_rating":"mean", "reviews_per_month":"mean",
                                                                           "id":"count"})

ratebyhood_dfg.rename(columns={'review_scores_rating':'avg rating', 'reviews_per_month':'avg # reviews / month', 'id':'# of properties'}, inplace=True)
#reset index to remove mult-index
ratebyhood_dfg = ratebyhood_dfg.rename_axis(['neighbourhood', 'Room_type']).reset_index()

ratebyhood_dfg.head(40)
# Out:
#                                         neighbourhood        Room_type  \
# 0                Brightwood Park, Crestwood, Petworth  Entire home/apt
# 1                       Brookland, Brentwood, Langdon  Entire home/apt
# 2                          Capitol Hill, Lincoln Park  Entire home/apt
# 3     Capitol View, Marshall Heights, Benning Heights  Entire home/apt
# 4      Cathedral Heights, McLean Gardens, Glover Park  Entire home/apt
# 5   Cleveland Park, Woodley Park, Massachusetts Av...  Entire home/apt
# 6   Colonial Village, Shepherd Park, North Portal ...  Entire home/apt
# 7   Columbia Heights, Mt. Pleasant, Pleasant Plain...  Entire home/apt
# 8    Congress Heights, Bellevue, Washington Highlands  Entire home/apt
# 9   Deanwood, Burrville, Grant Park, Lincoln Heigh...  Entire home/apt
# 10                           Douglas, Shipley Terrace  Entire home/apt
# 11  Downtown, Chinatown, Penn Quarters, Mount Vern...  Entire home/apt
# 12         Dupont Circle, Connecticut Avenue/K Street  Entire home/apt
# 13                       Eastland Gardens, Kenilworth  Entire home/apt
# 14  Edgewood, Bloomingdale, Truxton Circle, Eckington  Entire home/apt
# 15  Fairfax Village, Naylor Gardens, Hillcrest, Su...  Entire home/apt
# 16  Friendship Heights, American University Park, ...  Entire home/apt
# 17                    Georgetown, Burleith/Hillandale  Entire home/apt
# 18              Hawthorne, Barnaby Woods, Chevy Chase  Entire home/apt
# 19                                 Historic Anacostia  Entire home/apt
# 20     Howard University, Le Droit Park, Cardozo/Shaw  Entire home/apt
# 21     Ivy City, Arboretum, Trinidad, Carver Langston  Entire home/apt
# 22     Kalorama Heights, Adams Morgan, Lanier Heights  Entire home/apt
# 23  Lamont Riggs, Queens Chapel, Fort Totten, Plea...  Entire home/apt
# 24               Mayfair, Hillbrook, Mahaning Heights  Entire home/apt
# 25                          Near Southeast, Navy Yard  Entire home/apt
# 26       North Cleveland Park, Forest Hills, Van Ness  Entire home/apt
# 27  North Michigan Park, Michigan Park, University...  Entire home/apt
# 28      River Terrace, Benning, Greenway, Dupont Park  Entire home/apt
# 29                                 Shaw, Logan Circle  Entire home/apt
# 30                  Sheridan, Barry Farm, Buena Vista  Entire home/apt
# 31  Southwest Employment Area, Southwest/Waterfron...  Entire home/apt
# 32  Spring Valley, Palisades, Wesley Heights, Foxh...  Entire home/apt
# 33                     Takoma, Brightwood, Manor Park  Entire home/apt
# 34  Twining, Fairlawn, Randle Highlands, Penn Bran...  Entire home/apt
# 35          Union Station, Stanton Park, Kingman Park  Entire home/apt
# 36                        West End, Foggy Bottom, GWU  Entire home/apt
# 37  Woodland/Fort Stanton, Garfield Heights, Knox ...  Entire home/apt
# 38                   Woodridge, Fort Lincoln, Gateway  Entire home/apt
#
#     avg rating  avg # reviews / month  # of properties
# 0    95.586873               2.023436              302
# 1    95.783784               2.369865               84
# 2    96.608939               2.156451              651
# 3    94.333333               2.354667               19
# 4    96.176471               1.384630               81
# 5    95.486111               1.556622               98
# 6    97.444444               1.535556               14
# 7    95.243421               1.851828              566
# 8    93.212121               2.097879               44
# 9    91.444444               2.691111               12
# 10   95.285714               4.590000               10
# 11   95.073276               1.331857              359
# 12   95.547315               1.739077              582
# 13   97.666667               2.733333                3
# 14   95.100796               2.599869              457
# 15   97.166667               1.630000               15
# 16   96.369565               1.969362               61
# 17   94.481250               1.931472              197
# 18   93.960000               1.275385               36
# 19   92.733333               2.188667               18
# 20   95.171717               1.897850              248
# 21   93.769231               2.605191              154
# 22   95.477178               1.599184              311
# 23   95.714286               1.743061               61
# 24   92.307692               2.003077               17
# 25   92.083333               1.065833               54
# 26   93.000000               0.831714               50
# 27   94.615385               2.124750               48
# 28   95.357143               1.735714               18
# 29   96.031977               2.081532              445
# 30   97.375000               2.395000               11
# 31   93.046154               1.482794              100
# 32   92.733333               1.119167               65
# 33   94.229730               1.654933               91
# 34   90.509804               2.210588               69
# 35   95.987061               2.280657              672
# 36   92.914573               1.774853              309
# 37   89.750000               4.970000                4
# 38   96.323529               1.367143               43

# %%
###  merge the 2 dataframes

byhood_df = pd.merge(prcbyhood_dfg, ratebyhood_dfg, on=['neighbourhood'])
del byhood_df["Room_type_y"]
byhood_df.rename(columns={'Room_type_x':'Room_type'}, inplace=True)
#byhood_df.sort_values(by=['median rent'], ascending=False)
byhood_df.head()
# Out:
#                                      neighbourhood        Room_type  max rent  \
# 0             Brightwood Park, Crestwood, Petworth  Entire home/apt    2500.0
# 1                    Brookland, Brentwood, Langdon  Entire home/apt    1638.0
# 2                       Capitol Hill, Lincoln Park  Entire home/apt    5995.0
# 3  Capitol View, Marshall Heights, Benning Heights  Entire home/apt     450.0
# 4   Cathedral Heights, McLean Gardens, Glover Park  Entire home/apt    1500.0
#
#    min rent  median rent   mean rent  avg rating  avg # reviews / month  \
# 0      35.0        100.0  180.629139   95.586873               2.023436
# 1      42.0         91.5  174.714286   95.783784               2.369865
# 2      50.0        150.0  264.990783   96.608939               2.156451
# 3      30.0         99.0  132.052632   94.333333               2.354667
# 4      50.0        115.0  272.604938   96.176471               1.384630
#
#    # of properties
# 0              302
# 1               84
# 2              651
# 3               19
# 4               81

# %%
###  Plot neighborhood v median rent  ###

plt.bar(byhood_df['neighbourhood'], byhood_df["median rent"], color = 'magenta')

plt.ylabel('median rent')
plt.xlabel('neighborhood')
plt.title('median rent by neighborhood')

plt.xticks(rotation='vertical')

# Get current size
fig_size = plt.rcParams["figure.figsize"]
 

#increase plot size horizontally by 8
fig_size[0] = 30
fig_size[1] = 5

plt.savefig("MedianPriceByHood.png")

plt.show()
fig_size
# Out:
# [30, 5]

# %%
sorted = byhood_df.sort_values('median rent', ascending = 'false')
sorted.head(40)
# Out:
#                                         neighbourhood        Room_type  \
# 9   Deanwood, Burrville, Grant Park, Lincoln Heigh...  Entire home/apt
# 10                           Douglas, Shipley Terrace  Entire home/apt
# 23  Lamont Riggs, Queens Chapel, Fort Totten, Plea...  Entire home/apt
# 33                     Takoma, Brightwood, Manor Park  Entire home/apt
# 19                                 Historic Anacostia  Entire home/apt
# 1                       Brookland, Brentwood, Langdon  Entire home/apt
# 34  Twining, Fairlawn, Randle Highlands, Penn Bran...  Entire home/apt
# 3     Capitol View, Marshall Heights, Benning Heights  Entire home/apt
# 27  North Michigan Park, Michigan Park, University...  Entire home/apt
# 21     Ivy City, Arboretum, Trinidad, Carver Langston  Entire home/apt
# 13                       Eastland Gardens, Kenilworth  Entire home/apt
# 0                Brightwood Park, Crestwood, Petworth  Entire home/apt
# 38                   Woodridge, Fort Lincoln, Gateway  Entire home/apt
# 8    Congress Heights, Bellevue, Washington Highlands  Entire home/apt
# 24               Mayfair, Hillbrook, Mahaning Heights  Entire home/apt
# 6   Colonial Village, Shepherd Park, North Portal ...  Entire home/apt
# 37  Woodland/Fort Stanton, Garfield Heights, Knox ...  Entire home/apt
# 4      Cathedral Heights, McLean Gardens, Glover Park  Entire home/apt
# 7   Columbia Heights, Mt. Pleasant, Pleasant Plain...  Entire home/apt
# 26       North Cleveland Park, Forest Hills, Van Ness  Entire home/apt
# 5   Cleveland Park, Woodley Park, Massachusetts Av...  Entire home/apt
# 15  Fairfax Village, Naylor Gardens, Hillcrest, Su...  Entire home/apt
# 14  Edgewood, Bloomingdale, Truxton Circle, Eckington  Entire home/apt
# 16  Friendship Heights, American University Park, ...  Entire home/apt
# 22     Kalorama Heights, Adams Morgan, Lanier Heights  Entire home/apt
# 25                          Near Southeast, Navy Yard  Entire home/apt
# 35          Union Station, Stanton Park, Kingman Park  Entire home/apt
# 18              Hawthorne, Barnaby Woods, Chevy Chase  Entire home/apt
# 12         Dupont Circle, Connecticut Avenue/K Street  Entire home/apt
# 20     Howard University, Le Droit Park, Cardozo/Shaw  Entire home/apt
# 28      River Terrace, Benning, Greenway, Dupont Park  Entire home/apt
# 2                          Capitol Hill, Lincoln Park  Entire home/apt
# 29                                 Shaw, Logan Circle  Entire home/apt
# 32  Spring Valley, Palisades, Wesley Heights, Foxh...  Entire home/apt
# 31  Southwest Employment Area, Southwest/Waterfron...  Entire home/apt
# 17                    Georgetown, Burleith/Hillandale  Entire home/apt
# 30                  Sheridan, Barry Farm, Buena Vista  Entire home/apt
# 36                        West End, Foggy Bottom, GWU  Entire home/apt
# 11  Downtown, Chinatown, Penn Quarters, Mount Vern...  Entire home/apt
#
#     max rent  min rent  median rent   mean rent  avg rating  \
# 9      500.0      35.0         82.5  129.500000   91.444444
# 10    1250.0      39.0         82.5  251.900000   95.285714
# 23    3500.0      37.0         87.0  170.114754   95.714286
# 33    1400.0      30.0         88.0  132.516484   94.229730
# 19     700.0      65.0         90.0  179.777778   92.733333
# 1     1638.0      42.0         91.5  174.714286   95.783784
# 34    1500.0      50.0         99.0  175.072464   90.509804
# 3      450.0      30.0         99.0  132.052632   94.333333
# 27    1000.0      49.0        100.0  141.395833   94.615385
# 21    1999.0      42.0        100.0  156.772727   93.769231
# 13     210.0      85.0        100.0  131.666667   97.666667
# 0     2500.0      35.0        100.0  180.629139   95.586873
# 38    1800.0      36.0        100.0  190.023256   96.323529
# 8     1000.0      55.0        100.0  170.272727   93.212121
# 24     750.0      49.0        108.0  167.294118   92.307692
# 6      850.0      50.0        110.0  222.000000   97.444444
# 37     300.0      79.0        112.5  151.000000   89.750000
# 4     1500.0      50.0        115.0  272.604938   96.176471
# 7     2000.0      10.0        115.0  177.593640   95.243421
# 26    1450.0      56.0        118.0  207.900000   93.000000
# 5     2400.0      40.0        119.5  237.836735   95.486111
# 15     350.0      74.0        120.0  151.533333   97.166667
# 14    2500.0      40.0        125.0  205.553611   95.100796
# 16     800.0      50.0        125.0  166.573770   96.369565
# 22    3200.0      20.0        125.0  212.334405   95.477178
# 25    1000.0      72.0        140.0  204.685185   92.083333
# 35    4000.0      33.0        144.5  266.647321   95.987061
# 18    3500.0      50.0        146.5  417.972222   93.960000
# 12    2000.0      39.0        148.5  204.551546   95.547315
# 20    1500.0      50.0        150.0  246.375000   95.171717
# 28    3300.0      56.0        150.0  357.722222   95.357143
# 2     5995.0      50.0        150.0  264.990783   96.608939
# 29    5000.0      46.0        169.0  291.096629   96.031977
# 32    5000.0      60.0        175.0  405.261538   92.733333
# 31    2499.0      50.0        177.5  321.390000   93.046154
# 17   10000.0      60.0        180.0  335.868020   94.481250
# 30    1500.0      58.0        200.0  322.909091   97.375000
# 36    1950.0      50.0        200.0  436.721683   92.914573
# 11    5500.0      45.0        200.0  329.370474   95.073276
#
#     avg # reviews / month  # of properties
# 9                2.691111               12
# 10               4.590000               10
# 23               1.743061               61
# 33               1.654933               91
# 19               2.188667               18
# 1                2.369865               84
# 34               2.210588               69
# 3                2.354667               19
# 27               2.124750               48
# 21               2.605191              154
# 13               2.733333                3
# 0                2.023436              302
# 38               1.367143               43
# 8                2.097879               44
# 24               2.003077               17
# 6                1.535556               14
# 37               4.970000                4
# 4                1.384630               81
# 7                1.851828              566
# 26               0.831714               50
# 5                1.556622               98
# 15               1.630000               15
# 14               2.599869              457
# 16               1.969362               61
# 22               1.599184              311
# 25               1.065833               54
# 35               2.280657              672
# 18               1.275385               36
# 12               1.739077              582
# 20               1.897850              248
# 28               1.735714               18
# 2                2.156451              651
# 29               2.081532              445
# 32               1.119167               65
# 31               1.482794              100
# 17               1.931472              197
# 30               2.395000               11
# 36               1.774853              309
# 11               1.331857              359

# %%
sorted.describe()
# Out:
#            max rent   min rent  median rent   mean rent  avg rating  \
# count     39.000000  39.000000     39.00000   39.000000   39.000000
# mean    2263.871795  47.871795    126.75641  228.056282   94.643632
# std     1952.839810  15.002069     34.53295   84.238889    1.895046
# min      210.000000  10.000000     82.50000  129.500000   89.750000
# 25%     1000.000000  39.000000    100.00000  168.704436   93.129138
# 50%     1638.000000  50.000000    118.00000  204.685185   95.171717
# 75%     2850.000000  55.500000    149.25000  269.626130   95.885422
# max    10000.000000  85.000000    200.00000  436.721683   97.666667
#
#        avg # reviews / month  # of properties
# count              39.000000        39.000000
# mean                2.024464       163.564103
# std                 0.795290       199.150802
# min                 0.831714         3.000000
# 25%                 1.577903        18.500000
# 50%                 1.931472        65.000000
# 75%                 2.245623       275.000000
# max                 4.970000       672.000000

# %%
###  Plot neighborhood v median rent  ###

plt.bar(byhood_df['neighbourhood'], byhood_df["# of properties"], color = 'teal')

plt.ylabel('property count')
plt.xlabel('neighborhood')
plt.title('# of prperties per neighborhood')

plt.xticks(rotation='vertical')

# Get current size
fig_size = plt.rcParams["figure.figsize"]
 

#increase plot size horizontally by 8
fig_size[0] = 30
fig_size[1] = 5

plt.savefig("propertyCntByHood.png")

plt.show()
fig_size
# Out:
# [30, 5]

# %%
#plt.scatter(byhood_df['neighbourhood'], byhood_df["# of properties"], color = 'teal')

neighborhood = byhood_df['neighbourhood']
density = byhood_df["# of properties"]
medprice = byhood_df["median rent"]

plt.scatter(density, medprice, marker = "o", color='orange', edgecolors = "black", alpha = 0.75)

plt.ylabel('Median Rental')
plt.xlabel('Density')
plt.title('DC Neighborhoods by Rent and Density')


fig_size[0] = 5
fig_size[1] = 5
 

plt.savefig("Scatter_Neighborhoods_Rent_Density.png")

plt.show()
#fig_size
